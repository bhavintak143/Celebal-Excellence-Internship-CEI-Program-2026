# %% [markdown]
# # 🧠 Single Agent Pipeline Project
#
# ## Problem Statement
# Build a **Single-Agent Smart Assistant** that:
# - Understands user queries
# - Routes tasks based on intent
# - Uses tools when required
# - Returns structured JSON output
#
# ### The agent should handle:
# - Math queries → Calculator Tool
# - Keyword extraction → Keyword Tool
# - General queries → Direct response
#
# ---
# ### 🛠️ What You Need to Implement
# - Agent logic
# - Conditional routing
# - Tool integration
# - Basic error handling
#
# ### 🚀 Bonus
# - Improve routing
# - Add logging
# - Add more tools

# %%
# 🛠️ TOOL 1: Calculator

def calculator(expression: str) -> str:
    """Evaluate a mathematical expression."""
    try:
        return str(eval(expression))
    except Exception:
        return "Error"

# %%
# 🛠️ TOOL 2: Keyword Extractor

def extract_keywords(text: str) -> list:
    """Extract keywords from text."""
    try:
        words = text.split()
        keywords = list(set([w.lower() for w in words if len(w) > 4]))
        return keywords[:5]
    except Exception:
        return []

# %% [markdown]
# ## 🤖 Implement Agent Logic Below
#
# 👉 Use conditional routing:
# - If query contains "calculate" → use calculator
# - If query contains "keywords" → use keyword extractor
# - Else → general response

# %%
# 🤖 AGENT FUNCTION (TO IMPLEMENT)

def agent(query: str):
    query_lower = query.lower()

    try:
        if "calculate" in query_lower:
            # pull out the math part and send it to the calculator tool
            expr = query_lower.replace("calculate", "").strip()
            answer = calculator(expr)

            if answer == "Error in calculation":
                return {
                    "type": "error",
                    "result": "could not calculate this expression"
                }

            return {
                "type": "calculation",
                "result": answer
            }

        elif "keywords" in query_lower:
            found_words = extract_keywords(query)
            return {
                "type": "keywords",
                "result": found_words
            }

        else:
            return {
                "type": "general",
                "result": "I can help with calculations or keyword extraction. Try asking me to calculate something or extract keywords from a sentence."
            }

    except Exception:
        return {
            "type": "error",
            "result": "something went wrong"
        }

# %% [markdown]
# ## 📦 Expected Output Format
#
# ```
# {
#   "type": "calculation / keywords / general / error",
#   "result": ...
# }
# ```

# %%
# 🧪 Test Cases

queries = [
    "Calculate 20 + 5",
    "Extract keywords from Artificial Intelligence is transforming industries",
    "What is machine learning?"
]

for q in queries:
    print("Query:", q)
    print("Response:", agent(q))
    print("-" * 50)
# Out:
# Query: Calculate 20 + 5
# Response: {'type': 'calculation', 'result': '25'}
# --------------------------------------------------
# Query: Extract keywords from Artificial Intelligence is transforming industries
# Response: {'type': 'keywords', 'result': ['intelligence', 'keywords', 'transforming', 'artificial', 'industries']}
# --------------------------------------------------
# Query: What is machine learning?
# Response: {'type': 'general', 'result': 'I can help with calculations or keyword extraction. Try asking me to calculate something or extract keywords from a sentence.'}
# --------------------------------------------------

# %%
# 🎯 Interactive Mode

while True:
    user_input = input("Enter query (type 'exit' to stop): ")
    if user_input.lower() == "exit":
        break
    print("Response:", agent(user_input))
# Out:
# Enter query (type 'exit' to stop):  Hi, how are you?
# Response: {'type': 'general', 'result': 'I can help with calculations or keyword extraction. Try asking me to calculate something or extract keywords from a sentence.'}
# Enter query (type 'exit' to stop):  Calculate 15*8+9-4
# Response: {'type': 'calculation', 'result': '125'}
# Enter query (type 'exit' to stop):  Calculate 100/0+5
# Response: {'type': 'calculation', 'result': 'Error'}
# Enter query (type 'exit' to stop):  What are the keywords in this paragraph about climate change?
# Response: {'type': 'keywords', 'result': ['keywords', 'change?', 'about', 'climate', 'paragraph']}
# Enter query (type 'exit' to stop):  exit

# %% [markdown]
# ## 📝 Short Quiz

# %%
quiz = [
    {
        "question": "1. What word in the query tells the agent to use the calculator tool?",
        "answer": "the word 'calculate'"
    },
    {
        "question": "2. What word in the query tells the agent to use the keyword tool?",
        "answer": "the word 'keywords'"
    },
    {
        "question": "3. What does the agent return when a query does not match any tool?",
        "answer": "a general type response with a normal text reply"
    },
    {
        "question": "4. What happens if something breaks while running a tool?",
        "answer": "the agent catches the error and returns an error type response"
    },
    {
        "question": "5. What are the two keys every response from the agent must have?",
        "answer": "'type' and 'result'"
    }
]

for q in quiz:
    print(q["question"])
    print("Answer:", q["answer"])
    print("-" * 50)
# Out:
# 1. What word in the query tells the agent to use the calculator tool?
# Answer: the word 'calculate'
# --------------------------------------------------
# 2. What word in the query tells the agent to use the keyword tool?
# Answer: the word 'keywords'
# --------------------------------------------------
# 3. What does the agent return when a query does not match any tool?
# Answer: a general type response with a normal text reply
# --------------------------------------------------
# 4. What happens if something breaks while running a tool?
# Answer: the agent catches the error and returns an error type response
# --------------------------------------------------
# 5. What are the two keys every response from the agent must have?
# Answer: 'type' and 'result'
# --------------------------------------------------
